# %%
a = 41
b = 2.4
c = "Python"
d = False

# %%
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
dodawanie = a+b
odejmowanie = a-b
dzielenie = a/b
potegowanie = a**b
print(dodawanie)
print(odejmowanie)
print(dzielenie)
print(potegowanie)
# Out:
# 43.4
# 38.6
# 17.083333333333336
# 7424.740102963017

# %%
print(f"Wartosc a to {a}, b to {b}")
# Out:
# Wartosc a to 41, b to 2.4
